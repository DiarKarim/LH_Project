# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# data = pd.read_csv('ptx_2_detailed.txt')
filename = 'ptx_3_detailed.txt'
data = pd.read_csv(filename, sep='\t', skiprows=8)

# %%
data
# Out:
#        Video Time   Neutral     Happy           Sad     Angry  Surprised  \
# 0    00:00:00.000  0.504534  0.000000  0.000000e+00  0.000000   0.000000
# 1    00:00:00.066  0.482500  0.000047  1.630000e-07  0.043294   0.000179
# 2    00:00:00.133  0.486283  0.000100  6.220000e-07  0.035456   0.000263
# 3    00:00:00.200  0.489442  0.000208  1.230000e-06  0.029037   0.000410
# 4    00:00:00.266  0.491621  0.000253  1.008000e-06  0.023781   0.001098
# ..            ...       ...       ...           ...       ...        ...
# 280  00:00:18.666  0.432590  0.000000  0.000000e+00  0.263322   0.007183
# 281  00:00:18.733  0.441803  0.000000  0.000000e+00  0.215651   0.007769
# 282  00:00:18.800  0.447561  0.000000  0.000000e+00  0.176610   0.007327
# 283  00:00:18.866  0.446667  0.000000  0.000000e+00  0.144637   0.008434
# 284  00:00:18.933  0.450466  0.000000  0.000000e+00  0.118453   0.007775
#
#            Scared  Disgusted
# 0    0.000000e+00   0.000000
# 1    0.000000e+00   0.000000
# 2    0.000000e+00   0.000000
# 3    0.000000e+00   0.000000
# 4    0.000000e+00   0.000000
# ..            ...        ...
# 280  2.790000e-07   0.055362
# 281  2.960000e-07   0.080037
# 282  3.330000e-07   0.099968
# 283  3.900000e-07   0.129433
# 284  4.490000e-07   0.144626
#
# [285 rows x 8 columns]

# %%
plt.plot(data['Video Time'], data['Neutral'],'r')
plt.plot(data['Video Time'], data['Happy'],'g')
plt.plot(data['Video Time'], data['Sad'],'b')

# %%
# data['Combined'] = np.sqrt(data['Neutral']**2 + data['Happy']**2 + data['Sad']**2)
# data['Average'] = (data['Neutral'] + 
#                    data['Happy'] + 
#                    data['Sad'] + 
#                    data['Angry'] + 
#                    data['Surprised'] + 
#                    data['Scared'] + 
#                    data['Disgusted']) / 7.0

# %%
valence = [] 
for d in range(len(data)):
    
    sad = data['Sad'][d]
    angry = data['Angry'][d]
    scared = data['Scared'][d]
    disgust = data['Disgusted'][d]
     
    maxNegative = np.max([sad, angry, scared, disgust])
    
    valence.append(data['Happy'][d] - maxNegative)

                   
data['Valence'] = valence

# %%
plt.plot(data['Video Time'], data['Valence'], 'k')
print([sad, angry, disgust, scared])
print(maxNegative)
# Out:
# [0.0, 0.1184528, 0.144626, 4.49e-07]
# 0.144626
