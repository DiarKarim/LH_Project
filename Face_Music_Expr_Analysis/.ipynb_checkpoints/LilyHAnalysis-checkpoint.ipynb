# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

from statannot import add_stat_annotation

# %%
# # data = pd.read_csv('ptx_2_detailed.txt')
# filename = 'ptx_3_detailed.txt'
# data = pd.read_csv(filename, sep='\t', skiprows=8)

# %%
# file[14:24]

# %% [markdown]
# ## Load all data

# %%
path = "C:/Users/VR-Lab/Documents/Projects/LH_Project/Face_Music_Expr_Analysis/Data_FaceRaw/"
files = os.listdir(path)

tmpDF = None
df = None

for file in files: 
    if "detailed" in file:
        tmpDF = pd.read_csv(path + file, sep='\t', skiprows=8)
        
        tmpDF.insert(0,"ParticipantID", file[0:13])
        tmpDF.insert(1,"Condition", file[14:24])
        
        if df is None:
            df = tmpDF
        else: 
            df = pd.concat((df,tmpDF))

# %% [markdown]
# ### Compute Valence as happy - most negative value from the negative emotions

# %%
def ValenceFunc(data_frame):
    valence = []
    for d in range(len(data_frame)):
        sad = data_frame['Sad'].iloc[d]
        angry = data_frame['Angry'].iloc[d]
        scared = data_frame['Scared'].iloc[d]
        disgust = data_frame['Disgusted'].iloc[d]
        maxNegative = np.max([sad, angry, scared, disgust])
        valence.append(data_frame['Happy'].iloc[d] - maxNegative)
    return pd.Series(valence, index=data_frame.index)

# %% [markdown]
# ### Add Valence back into the dataframe (df)

# %%
# df['Valence'] = df.groupby(['ParticipantID', 'Condition']).apply(lambda x: pd.Series(Valence(x))).values
df['Valence'] = df.groupby(['ParticipantID', 'Condition']).apply(ValenceFunc).reset_index(level=[0,1], drop=True)

df
# Out:
#       ParticipantID   Condition    Video Time   Neutral     Happy       Sad  \
# 0     Participant 1  Analysis 1  00:00:00.000  0.954493  0.000081  0.001521
# 1     Participant 1  Analysis 1  00:00:00.066  0.954519  0.000085  0.001531
# 2     Participant 1  Analysis 1  00:00:00.133  0.960262  0.000118  0.001359
# 3     Participant 1  Analysis 1  00:00:00.200  0.962831  0.000143  0.001218
# 4     Participant 1  Analysis 1  00:00:00.266  0.966000  0.000161  0.001127
# ...             ...         ...           ...       ...       ...       ...
# 2635  Participant 4  Analysis 2  00:02:55.666  0.790599  0.001154  0.199955
# 2636  Participant 4  Analysis 2  00:02:55.733  0.802554  0.001084  0.195664
# 2637  Participant 4  Analysis 2  00:02:55.800  0.831431  0.000900  0.169383
# 2638  Participant 4  Analysis 2  00:02:55.866  0.827056  0.000757  0.205605
# 2639  Participant 4  Analysis 2  00:02:55.933  0.812744  0.000626  0.261699
#
# ...

# %% [markdown]
# #### Save the data to a csv / excel file

# %%
df.to_csv("Raw_DataFrame.csv")

# %%
ptxID = "Participant 1"
condition = "Analysis 1"

mask = (df["ParticipantID"] == ptxID) & (df["Condition"] == condition)

df[mask]["Video Time"][-1-100:-1]
# Out:
# 2659    00:02:57.266
# 2660    00:02:57.333
# 2661    00:02:57.400
# 2662    00:02:57.466
# 2663    00:02:57.533
#             ...
# 2754    00:03:03.600
# 2755    00:03:03.666
# 2756    00:03:03.733
# 2757    00:03:03.800
# 2758    00:03:03.866
# Name: Video Time, Length: 100, dtype: object

# %%
print("Type: ", type(df["Video Time"][0].values))
df["Video Time"].values[0][-1-8:-1]
# Out:
# Type:  <class 'numpy.ndarray'>
# '00:00.00'

# %% [markdown]
# #### The following time conversion from string to float isn't working, because I am not converting the string values properly.
# We need to find a way to convert from unix time to seconds

# %%
df['Video Time'].values[200][-1-8:-1-3]
# Out:
# '00:13'

# %%
def time_to_seconds(data_frame):
    
    times = []
    
    for i in range(len(data_frame)):
    
        time_str = data_frame['Video Time'].values[i][-1-8:-1-3]
        # Split the string into hours and minutes
        minutes, seconds = time_str.split(':')

        # Convert hours and minutes to integers
        minutes = int(minutes)
        seconds = int(seconds)

        # Calculate total seconds
        total_seconds = (minutes * 60) + seconds
        
        times.append(total_seconds)

    return pd.Series(times, index=data_frame.index)
    # return total_seconds

# # Example usage
# time_str = "02:55"
# seconds = time_to_seconds(time_str)
# print(f"Time in seconds: {seconds}")

# %%
df['Time'] = df.groupby(['ParticipantID', 'Condition']).apply(time_to_seconds).reset_index(level=[0,1], drop=True)
df
# Out:
#       ParticipantID   Condition    Video Time   Neutral     Happy       Sad  \
# 0     Participant 1  Analysis 1  00:00:00.000  0.954493  0.000081  0.001521
# 1     Participant 1  Analysis 1  00:00:00.066  0.954519  0.000085  0.001531
# 2     Participant 1  Analysis 1  00:00:00.133  0.960262  0.000118  0.001359
# 3     Participant 1  Analysis 1  00:00:00.200  0.962831  0.000143  0.001218
# 4     Participant 1  Analysis 1  00:00:00.266  0.966000  0.000161  0.001127
# ...             ...         ...           ...       ...       ...       ...
# 2635  Participant 4  Analysis 2  00:02:55.666  0.790599  0.001154  0.199955
# 2636  Participant 4  Analysis 2  00:02:55.733  0.802554  0.001084  0.195664
# 2637  Participant 4  Analysis 2  00:02:55.800  0.831431  0.000900  0.169383
# 2638  Participant 4  Analysis 2  00:02:55.866  0.827056  0.000757  0.205605
# 2639  Participant 4  Analysis 2  00:02:55.933  0.812744  0.000626  0.261699
#
# ...

# %%
ptxID = pd.unique(df["ParticipantID"])[0]
condition = pd.unique(df["Condition"])[0]
mask = (df["ParticipantID"] == ptxID) & (df["Condition"] == condition)

plt.plot(df[mask]['Time'])

# %% [markdown]
# ### Example plot from a random participant and a random condition

# %%
ptxID = pd.unique(df["ParticipantID"])[2]
condition = pd.unique(df["Condition"])[1]

mask = (df["ParticipantID"] == ptxID) & (df["Condition"] == condition)

plt.figure()
plt.plot(df[mask]['Valence'])
plt.ylim([-1, 1])

# plt.figure()
# plt.plot(df[mask]['Video Time'])
# Out:
# (-1.0, 1.0)

# %% [markdown]
# ### Raw data plotting isn't appropriate, because we need to normalise all responses across the participants

# %%
sns.lineplot(data=df, x='Time',y='Valence', hue='Condition')
# Out:
# <Axes: xlabel='Time', ylabel='Valence'>

# %% [markdown]
# ### The need to normalise responses is illustrated below, here participant 4 has a much higher average response compared to the other participants

# %%
sns.barplot(data=df, x = "Condition", y = "Valence", hue="ParticipantID")
# Out:
# <Axes: xlabel='Condition', ylabel='Valence'>

# %% [markdown]
# ### To normalise we need to compare the responses of each participant across the trial and normalise all other participant to lie in between the highest and lowest response

# %%
condition1 = pd.unique(df["Condition"])[0]
exclude_ptxID = pd.unique(df["ParticipantID"])[3]
mask = (df["Condition"] == condition1)  & (df["ParticipantID"] != exclude_ptxID)

# %%
sns.lineplot(data=df[mask], x='Time',y='Valence', hue='ParticipantID')
# Out:
# <Axes: xlabel='Time', ylabel='Valence'>

# %%
condition1 = pd.unique(df["Condition"])[1]
exclude_ptxID = pd.unique(df["ParticipantID"])[3]
mask = (df["Condition"] == condition1)  & (df["ParticipantID"] != exclude_ptxID)

# %%
sns.lineplot(data=df[mask], x='Time',y='Valence', hue='ParticipantID')
# Out:
# <Axes: xlabel='Time', ylabel='Valence'>

# %%
def change_range(x, min_val = -0.89, max_val = 0.98):    
    # # Calculate the minimum and maximum values in x.
    # min_val = np.min(x)
    # max_val = np.max(x)

    # Calculate the range of values.
    range_val = max_val - min_val

    # Scale all values in x to be between 0 and 1.
    scaled_x = (x - min_val) / range_val

    # Shift all values in x to be between -1 and 1.
    shifted_x = scaled_x * 2 - 1

    return shifted_x

# %%
# ptxID = pd.unique(df["ParticipantID"])[3]
# condition = pd.unique(df["Condition"])[1]

# mask = (df["ParticipantID"] == ptxID) & (df["Condition"] == condition)

# normalisedValue = change_range(df[mask]['Valence'].values)

# plt.figure()
# plt.plot(df[mask]['Valence'],'r')
# plt.plot(normalisedValue,'g')
# plt.ylim([-1.5, 1.5])

# %%
sns.barplot(data=df, x = "Condition", y = "Valence")
# Out:
# <Axes: xlabel='Condition', ylabel='Valence'>

# %% [markdown]
# ### Same bar chart as above but with statistical annotations and results

# %%
# mask = (df['ParticipantID'] == 'Participant 1') & (df['Condition'] == 'Analysis 2')
# len(df[mask]['Valence'])

# %%
x = "Condition"
y = "Valence"
box_pairs = [("Analysis 1", "Analysis 2"),]


ax = sns.barplot(data=df, x = x, y = y[0:2200])
test_results = add_stat_annotation(ax, data=df, x=x, y=y[0:2200],
                                   box_pairs=box_pairs,
                                   test='t-test_paired', text_format='star',
                                   loc='outside', verbose=2)
test_results

plt.savefig('valence.png',dpi=300, bbox_inches='tight')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22192\872301156.py in ?()
#       3 box_pairs = [("Analysis 1", "Analysis 2"),]
#       4
#       5
#       6 ax = sns.barplot(data=df, x = x, y = y)
# ----> 7 test_results = add_stat_annotation(ax, data=df, x=x, y=y,
#       8                                    box_pairs=box_pairs,
#       9                                    test='t-test_paired', text_format='star',
#      10                                    loc='outside', verbose=2)
#
# ...
